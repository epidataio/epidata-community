# %% [markdown]
# <h1 style="text-align:center;text-decoration: underline">Stream Analytics Tutorial</h1>
# <h1>Overview</h1>
# <p>Welcome to the stream analytics tutorial for EpiData Lite. In this tutorial we will perform near real-time stream analytics on sample weather data acquired from a simulated wireless sensor network.</p>

# %% [markdown]
# <h2>Package and Module Imports</h2>
# <p>As a first step, we will import packages and modules required for this tutorial. Since <i>EpiData Lite Context (ec)</i> is required to use the application, it is implicitly imported. Sample functions for near real-time analytics are avaialable in <i>EpiData Analytics</i> package. Other packages and modules, such as <i>datetime</i>, <i>pandas</i> and <i>matplotlib</i>, can also be imported at this time.</p>

# %%
import sys
sys.path.append("/Users/srinibadri/Documents/Repos/epidata/epidata-community-interns/ipython")
sys.path.append("/Users/srinibadri/Documents/Repos/epidata/epidata-community-interns/ipython/epidata")

from epidata.EpidataLiteContext import EpidataLiteContext
from epidata.EpidataLiteStreamingContext import EpidataLiteStreamingContext
#from epidata.analytics import *

# %matplotlib inline
from datetime import datetime, timedelta
import pandas as pd
import time
import pylab as pl
from IPython import display
import json

ec = EpidataLiteContext()
esc = EpidataLiteStreamingContext()
# Out:
# gateway:  <py4j.java_gateway.JavaGateway object at 0x0000012652EBDC10>
# gg:  <py4j.java_gateway.JavaGateway object at 0x0000012653DE5F70>
# jelc:  com.epidata.spark.EpidataLiteContext@6f34d0dc
# jesc:  com.epidata.spark.EpidataLiteStreamingContext@4be66ffb

# %% [markdown]
# <h2>Stream Analysis</h2>
# <h3>Function Definition</h3>
# <p>EpiData supports development and deployment of custom algorithms via Jupyter Notebook. Below, we define python functions for substituting extreme outliers and aggregating temperature measurements. These functions can be operated on near real-time and historic data. In this tutorial, we will apply the functions on near real-time data being ingested to the platform</p>

# %%
import pandas as pd
import math, numbers

def identity_demo(df, meas_names=[], params={}):
    """
    Returns input dataframe without changing it.
    """
    
    return df

# %%
import pandas as pd
import math, numbers
import json
import numpy as np

def substitute_demo(df, meas_names, gateway, method="rolling", size=3):
    """
    Substitute missing measurement values within a data frame, using the specified method.
    """
    print(df)
    df["meas_value"].replace(250, np.nan, inplace=True)
    
    for meas_name in meas_names:

        if (method == "rolling"):
            if ((size % 2 == 0) and (size != 0)): size += 1   
            if df.loc[df["meas_name"]==meas_name].size > 0:
                indices = df.loc[df["meas_name"] == meas_name].index[df.loc[df["meas_name"] == meas_name]["meas_value"].apply(
                    lambda x: not isinstance(x, str) and (x == None or np.isnan(x)))]
                substitutes = df.loc[df["meas_name"]==meas_name]["meas_value"].rolling( window=size, min_periods=1, center=True).mean()
            
                df["meas_value"].fillna(substitutes, inplace=True)
                df.loc[indices, "meas_flag"] = "substituted"
                df.loc[indices, "meas_method"] = "rolling average"
        else:
            raise ValueError("Unsupported substitution method: ", repr(method))
    print(df)
    return df

# %%
import pandas as pd
import numpy as np
import json

def subgroup_statistics(row):
    row['start_time'] = np.min(row["ts"])
    row["stop_time"] = np.max(row["ts"])
    row["meas_summary_name"] = "statistics"
    row["meas_summary_value"] = json.dumps({'count': row["meas_value"].count(), 'mean': row["meas_value"].mean(),
                                            'std': row["meas_value"].std(), 'min': row["meas_value"].min(), 
                                            'max': row["meas_value"].max()})
    row["meas_summary_description"] = "descriptive statistics"
    return row

def meas_statistics_demo(df, meas_names, method="standard"):
    """
    Compute statistics on measurement values within a data frame, using the specified method.
    """
    
    if (method == "standard"):
        df_grouped = df.loc[df["meas_name"].isin(meas_names)].groupby(["company", "site", "station", "sensor"], 
                            as_index=False)
        df_summary = df_grouped.apply(subgroup_statistics).loc[:, ["company", "site", "station", "sensor",
            "start_time", "stop_time", "event", "meas_name", "meas_summary_name", "meas_summary_value", 
            "meas_summary_description"]].drop_duplicates()
    else:
        raise ValueError("Unsupported summary method: ", repr(method))
                
    return df_summary

# %% [markdown]
# <h3>Transformations and Streams</h3>
# <p>The analytics algorithms are executed on near real-time data through transformations. A transformation specifies the function, its parameters and destination. The destination can be one of the pre-defined topics, namely <i>'measurements_cleansed'</i> or <i>'measurements_summary'</i>, or another custom topic.</p>
# <p>Once the transformations are defined, they are initiated via <i>ec.create_stream(source_topic, destination_topic, transformation)</i> function call.</p>

# %%
# Define tranformations and steam operations
op1 = esc.create_transformation(substitute_demo, ["Temperature", "Wind_Speed"], {})
# {"method": "rolling", "s": 3}
# op1 = esc.create_transformation("Identity", ["Temperature", "Wind_Speed"], {})
# op1 = esc.create_transformation(identity_demo, ["Temperature", "Wind_Speed"], {})
esc.create_stream("measurements_original", "measurements_cleansed", op1)

#op2 = esc.create_transformation("identity", ["Temperature", "Wind_Speed"], {})
#esc.create_stream("measurements_substituted_1", "measurements_cleansed", op2)

#op3 = esc.create_transformation("meas_statistics", ["Temperature", "Wind_Speed"], {"method": "standard"})
#esc.create_stream("measurements_substituted_1", "measurements_summary", op3)

# Start near real-time processing
esc.start_streaming()
# Out:
# stream created
# streams started
# [{'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 70.68, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661878983767}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 9.12, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661878983767}, {'meas_value': 64.43, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661878983767}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 71.29, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661878984087}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 10.14, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661878984087}]
#
# [{'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 70.68, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661878983767}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 9.12, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661878983767}, {'meas_value': 64.43, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661878983767}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 71.29, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661878984087}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 10.14, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661878984087}]
#
#    company event meas_datatype  meas_lower_limit          meas_name  \
# 0  EpiData  none        double              10.1        Temperature
# 1  EpiData  none        double               0.0         Wind_Speed
# 2  EpiData  none        double               NaN  Relative_Humidity
# 3  EpiData  none        double              10.1        Temperature
# 4  EpiData  none        double               0.0         Wind_Speed
#
#   meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 0        PASS     deg F             120.4       70.68  Temperature_Probe
# 1        PASS       mph              25.0        9.12         Anemometer
# 2        PASS         %               NaN       64.43           RH_Probe
# 3        PASS     deg F             120.4       71.29  Temperature_Probe
# 4        PASS       mph              25.0       10.14         Anemometer
#
#             site station             ts
# 0  San_Francisco   WSN-1  1661878983767
# 1  San_Francisco   WSN-1  1661878983767
# 2  San_Francisco   WSN-1  1661878983767
# 3  San_Francisco   WSN-1  1661878984087
# 4  San_Francisco   WSN-1  1661878984087
#
#    company event meas_datatype  meas_lower_limit          meas_name  \
# 0  EpiData  none        double              10.1        Temperature
# 1  EpiData  none        double               0.0         Wind_Speed
# 2  EpiData  none        double               NaN  Relative_Humidity
# 3  EpiData  none        double              10.1        Temperature
# 4  EpiData  none        double               0.0         Wind_Speed
#
#   meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 0        PASS     deg F             120.4       70.68  Temperature_Probe
# 1        PASS       mph              25.0        9.12         Anemometer
# 2        PASS         %               NaN       64.43           RH_Probe
# 3        PASS     deg F             120.4       71.29  Temperature_Probe
# 4        PASS       mph              25.0       10.14         Anemometer
#
#             site station             ts meas_flag meas_method
# 0  San_Francisco   WSN-1  1661878983767       NaN         NaN
# 1  San_Francisco   WSN-1  1661878983767       NaN         NaN
# 2  San_Francisco   WSN-1  1661878983767       NaN         NaN
# 3  San_Francisco   WSN-1  1661878984087       NaN         NaN
# 4  San_Francisco   WSN-1  1661878984087       NaN         NaN
#
# [{'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 10.1, 'meas_name': 'Temperature', 'meas_status': 'PASS', 'meas_unit': 'deg F', 'meas_upper_limit': 120.4, 'meas_value': 70.68, 'sensor': 'Temperature_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661878983767, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 0.0, 'meas_name': 'Wind_Speed', 'meas_status': 'PASS', 'meas_unit': 'mph', 'meas_upper_limit': 25.0, 'meas_value': 9.12, 'sensor': 'Anemometer', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661878983767, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': nan, 'meas_name': 'Relative_Humidity', 'meas_status': 'PASS', 'meas_unit': '%', 'meas_upper_limit': nan, 'meas_value': 64.43, 'sensor': 'RH_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661878983767, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 10.1, 'meas_name': 'Temperature', 'meas_status': 'PASS', 'meas_unit': 'deg F', 'meas_upper_limit': 120.4, 'meas_value': 71.29, 'sensor': 'Temperature_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661878984087, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 0.0, 'meas_name': 'Wind_Speed', 'meas_status': 'PASS', 'meas_unit': 'mph', 'meas_upper_limit': 25.0, 'meas_value': 10.14, 'sensor': 'Anemometer', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661878984087, 'meas_flag': nan, 'meas_method': nan}]
#
# [{'meas_value': 68.0, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661878984087}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 71.7, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661878984262}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 5.51, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661878984262}, {'meas_value': 54.67, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661878984262}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 72.38000000000001, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661878984418}]
#
# [{'meas_value': 68.0, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661878984087}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 71.7, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661878984262}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 5.51, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661878984262}, {'meas_value': 54.67, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661878984262}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 72.38000000000001, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661878984418}]
#
#    company event meas_datatype  meas_lower_limit          meas_name  \
# 0  EpiData  none        double               NaN  Relative_Humidity
# 1  EpiData  none        double              10.1        Temperature
# 2  EpiData  none        double               0.0         Wind_Speed
# 3  EpiData  none        double               NaN  Relative_Humidity
# 4  EpiData  none        double              10.1        Temperature
#
#   meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 0        PASS         %               NaN       68.00           RH_Probe
# 1        PASS     deg F             120.4       71.70  Temperature_Probe
# 2        PASS       mph              25.0        5.51         Anemometer
# 3        PASS         %               NaN       54.67           RH_Probe
# 4        PASS     deg F             120.4       72.38  Temperature_Probe
#
#             site station             ts
# 0  San_Francisco   WSN-1  1661878984087
# 1  San_Francisco   WSN-1  1661878984262
# 2  San_Francisco   WSN-1  1661878984262
# 3  San_Francisco   WSN-1  1661878984262
# 4  San_Francisco   WSN-1  1661878984418
#
#    company event meas_datatype  meas_lower_limit          meas_name  \
# 0  EpiData  none        double               NaN  Relative_Humidity
# 1  EpiData  none        double              10.1        Temperature
# 2  EpiData  none        double               0.0         Wind_Speed
# 3  EpiData  none        double               NaN  Relative_Humidity
# 4  EpiData  none        double              10.1        Temperature
#
#   meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 0        PASS         %               NaN       68.00           RH_Probe
# 1        PASS     deg F             120.4       71.70  Temperature_Probe
# 2        PASS       mph              25.0        5.51         Anemometer
# 3        PASS         %               NaN       54.67           RH_Probe
# 4        PASS     deg F             120.4       72.38  Temperature_Probe
#
#             site station             ts meas_flag meas_method
# 0  San_Francisco   WSN-1  1661878984087       NaN         NaN
# 1  San_Francisco   WSN-1  1661878984262       NaN         NaN
# 2  San_Francisco   WSN-1  1661878984262       NaN         NaN
# 3  San_Francisco   WSN-1  1661878984262       NaN         NaN
# 4  San_Francisco   WSN-1  1661878984418       NaN         NaN
#
# [{'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': nan, 'meas_name': 'Relative_Humidity', 'meas_status': 'PASS', 'meas_unit': '%', 'meas_upper_limit': nan, 'meas_value': 68.0, 'sensor': 'RH_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661878984087, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 10.1, 'meas_name': 'Temperature', 'meas_status': 'PASS', 'meas_unit': 'deg F', 'meas_upper_limit': 120.4, 'meas_value': 71.7, 'sensor': 'Temperature_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661878984262, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 0.0, 'meas_name': 'Wind_Speed', 'meas_status': 'PASS', 'meas_unit': 'mph', 'meas_upper_limit': 25.0, 'meas_value': 5.51, 'sensor': 'Anemometer', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661878984262, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': nan, 'meas_name': 'Relative_Humidity', 'meas_status': 'PASS', 'meas_unit': '%', 'meas_upper_limit': nan, 'meas_value': 54.67, 'sensor': 'RH_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661878984262, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 10.1, 'meas_name': 'Temperature', 'meas_status': 'PASS', 'meas_unit': 'deg F', 'meas_upper_limit': 120.4, 'meas_value': 72.38000000000001, 'sensor': 'Temperature_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661878984418, 'meas_flag': nan, 'meas_method': nan}]
# [{'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 5.97, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661878984418}, {'meas_value': 60.81, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661878984418}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 70.7, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879067940}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 10.26, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879067940}, {'meas_value': 64.58, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879067940}]
#
# [{'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 5.97, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661878984418}, {'meas_value': 60.81, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661878984418}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 70.7, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879067940}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 10.26, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879067940}, {'meas_value': 64.58, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879067940}]
#
#    company event meas_datatype  meas_lower_limit          meas_name  \
# 0  EpiData  none        double               0.0         Wind_Speed
# 1  EpiData  none        double               NaN  Relative_Humidity
# 2  EpiData  none        double              10.1        Temperature
# 3  EpiData  none        double               0.0         Wind_Speed
# 4  EpiData  none        double               NaN  Relative_Humidity
#
#   meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 0        PASS       mph              25.0        5.97         Anemometer
# 1        PASS         %               NaN       60.81           RH_Probe
# 2        PASS     deg F             120.4       70.70  Temperature_Probe
# 3        PASS       mph              25.0       10.26         Anemometer
# 4        PASS         %               NaN       64.58           RH_Probe
#
#             site station             ts
# 0  San_Francisco   WSN-1  1661878984418
# 1  San_Francisco   WSN-1  1661878984418
# 2  San_Francisco   WSN-1  1661879067940
# 3  San_Francisco   WSN-1  1661879067940
# 4  San_Francisco   WSN-1  1661879067940
#
#    company event meas_datatype  meas_lower_limit          meas_name  \
# 0  EpiData  none        double               0.0         Wind_Speed
# 1  EpiData  none        double               NaN  Relative_Humidity
# 2  EpiData  none        double              10.1        Temperature
# 3  EpiData  none        double               0.0         Wind_Speed
# 4  EpiData  none        double               NaN  Relative_Humidity
#
#   meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 0        PASS       mph              25.0        5.97         Anemometer
# 1        PASS         %               NaN       60.81           RH_Probe
# 2        PASS     deg F             120.4       70.70  Temperature_Probe
# 3        PASS       mph              25.0       10.26         Anemometer
# 4        PASS         %               NaN       64.58           RH_Probe
#
#             site station             ts meas_flag meas_method
# 0  San_Francisco   WSN-1  1661878984418       NaN         NaN
# 1  San_Francisco   WSN-1  1661878984418       NaN         NaN
# 2  San_Francisco   WSN-1  1661879067940       NaN         NaN
# 3  San_Francisco   WSN-1  1661879067940       NaN         NaN
# 4  San_Francisco   WSN-1  1661879067940       NaN         NaN
#
# [{'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 0.0, 'meas_name': 'Wind_Speed', 'meas_status': 'PASS', 'meas_unit': 'mph', 'meas_upper_limit': 25.0, 'meas_value': 5.97, 'sensor': 'Anemometer', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661878984418, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': nan, 'meas_name': 'Relative_Humidity', 'meas_status': 'PASS', 'meas_unit': '%', 'meas_upper_limit': nan, 'meas_value': 60.81, 'sensor': 'RH_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661878984418, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 10.1, 'meas_name': 'Temperature', 'meas_status': 'PASS', 'meas_unit': 'deg F', 'meas_upper_limit': 120.4, 'meas_value': 70.7, 'sensor': 'Temperature_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879067940, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 0.0, 'meas_name': 'Wind_Speed', 'meas_status': 'PASS', 'meas_unit': 'mph', 'meas_upper_limit': 25.0, 'meas_value': 10.26, 'sensor': 'Anemometer', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879067940, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': nan, 'meas_name': 'Relative_Humidity', 'meas_status': 'PASS', 'meas_unit': '%', 'meas_upper_limit': nan, 'meas_value': 64.58, 'sensor': 'RH_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879067940, 'meas_flag': nan, 'meas_method': nan}]
#
# [{'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 70.7, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879068091}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 9.04, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879068091}, {'meas_value': 57.51, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879068091}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 70.98, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879068261}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 9.75, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879068261}]
#
# [{'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 70.7, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879068091}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 9.04, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879068091}, {'meas_value': 57.51, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879068091}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 70.98, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879068261}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 9.75, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879068261}]
#
#    company event meas_datatype  meas_lower_limit          meas_name  \
# 0  EpiData  none        double              10.1        Temperature
# 1  EpiData  none        double               0.0         Wind_Speed
# 2  EpiData  none        double               NaN  Relative_Humidity
# 3  EpiData  none        double              10.1        Temperature
# 4  EpiData  none        double               0.0         Wind_Speed
#
#   meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 0        PASS     deg F             120.4       70.70  Temperature_Probe
# 1        PASS       mph              25.0        9.04         Anemometer
# 2        PASS         %               NaN       57.51           RH_Probe
# 3        PASS     deg F             120.4       70.98  Temperature_Probe
# 4        PASS       mph              25.0        9.75         Anemometer
#
#             site station             ts
# 0  San_Francisco   WSN-1  1661879068091
# 1  San_Francisco   WSN-1  1661879068091
# 2  San_Francisco   WSN-1  1661879068091
# 3  San_Francisco   WSN-1  1661879068261
# 4  San_Francisco   WSN-1  1661879068261
#
#    company event meas_datatype  meas_lower_limit          meas_name  \
# 0  EpiData  none        double              10.1        Temperature
# 1  EpiData  none        double               0.0         Wind_Speed
# 2  EpiData  none        double               NaN  Relative_Humidity
# 3  EpiData  none        double              10.1        Temperature
# 4  EpiData  none        double               0.0         Wind_Speed
#
#   meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 0        PASS     deg F             120.4       70.70  Temperature_Probe
# 1        PASS       mph              25.0        9.04         Anemometer
# 2        PASS         %               NaN       57.51           RH_Probe
# 3        PASS     deg F             120.4       70.98  Temperature_Probe
# 4        PASS       mph              25.0        9.75         Anemometer
#
#             site station             ts meas_flag meas_method
# 0  San_Francisco   WSN-1  1661879068091       NaN         NaN
# 1  San_Francisco   WSN-1  1661879068091       NaN         NaN
# 2  San_Francisco   WSN-1  1661879068091       NaN         NaN
# 3  San_Francisco   WSN-1  1661879068261       NaN         NaN
# 4  San_Francisco   WSN-1  1661879068261       NaN         NaN
#
# [{'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 10.1, 'meas_name': 'Temperature', 'meas_status': 'PASS', 'meas_unit': 'deg F', 'meas_upper_limit': 120.4, 'meas_value': 70.7, 'sensor': 'Temperature_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879068091, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 0.0, 'meas_name': 'Wind_Speed', 'meas_status': 'PASS', 'meas_unit': 'mph', 'meas_upper_limit': 25.0, 'meas_value': 9.04, 'sensor': 'Anemometer', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879068091, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': nan, 'meas_name': 'Relative_Humidity', 'meas_status': 'PASS', 'meas_unit': '%', 'meas_upper_limit': nan, 'meas_value': 57.51, 'sensor': 'RH_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879068091, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 10.1, 'meas_name': 'Temperature', 'meas_status': 'PASS', 'meas_unit': 'deg F', 'meas_upper_limit': 120.4, 'meas_value': 70.98, 'sensor': 'Temperature_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879068261, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 0.0, 'meas_name': 'Wind_Speed', 'meas_status': 'PASS', 'meas_unit': 'mph', 'meas_upper_limit': 25.0, 'meas_value': 9.75, 'sensor': 'Anemometer', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879068261, 'meas_flag': nan, 'meas_method': nan}]
# [{'meas_value': 58.7, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879068261}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 71.14, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879068435}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 9.52, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879068435}, {'meas_value': 65.51, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879068435}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 70.52, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879070675}]
#
# [{'meas_value': 58.7, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879068261}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 71.14, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879068435}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 9.52, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879068435}, {'meas_value': 65.51, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879068435}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 70.52, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879070675}]
#
#    company event meas_datatype  meas_lower_limit          meas_name  \
# 0  EpiData  none        double               NaN  Relative_Humidity
# 1  EpiData  none        double              10.1        Temperature
# 2  EpiData  none        double               0.0         Wind_Speed
# 3  EpiData  none        double               NaN  Relative_Humidity
# 4  EpiData  none        double              10.1        Temperature
#
#   meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 0        PASS         %               NaN       58.70           RH_Probe
# 1        PASS     deg F             120.4       71.14  Temperature_Probe
# 2        PASS       mph              25.0        9.52         Anemometer
# 3        PASS         %               NaN       65.51           RH_Probe
# 4        PASS     deg F             120.4       70.52  Temperature_Probe
#
#             site station             ts
# 0  San_Francisco   WSN-1  1661879068261
# 1  San_Francisco   WSN-1  1661879068435
# 2  San_Francisco   WSN-1  1661879068435
# 3  San_Francisco   WSN-1  1661879068435
# 4  San_Francisco   WSN-1  1661879070675
#
#    company event meas_datatype  meas_lower_limit          meas_name  \
# 0  EpiData  none        double               NaN  Relative_Humidity
# 1  EpiData  none        double              10.1        Temperature
# 2  EpiData  none        double               0.0         Wind_Speed
# 3  EpiData  none        double               NaN  Relative_Humidity
# 4  EpiData  none        double              10.1        Temperature
#
#   meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 0        PASS         %               NaN       58.70           RH_Probe
# 1        PASS     deg F             120.4       71.14  Temperature_Probe
# 2        PASS       mph              25.0        9.52         Anemometer
# 3        PASS         %               NaN       65.51           RH_Probe
# 4        PASS     deg F             120.4       70.52  Temperature_Probe
#
#             site station             ts meas_flag meas_method
# 0  San_Francisco   WSN-1  1661879068261       NaN         NaN
# 1  San_Francisco   WSN-1  1661879068435       NaN         NaN
# 2  San_Francisco   WSN-1  1661879068435       NaN         NaN
# 3  San_Francisco   WSN-1  1661879068435       NaN         NaN
# 4  San_Francisco   WSN-1  1661879070675       NaN         NaN
#
# [{'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': nan, 'meas_name': 'Relative_Humidity', 'meas_status': 'PASS', 'meas_unit': '%', 'meas_upper_limit': nan, 'meas_value': 58.7, 'sensor': 'RH_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879068261, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 10.1, 'meas_name': 'Temperature', 'meas_status': 'PASS', 'meas_unit': 'deg F', 'meas_upper_limit': 120.4, 'meas_value': 71.14, 'sensor': 'Temperature_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879068435, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 0.0, 'meas_name': 'Wind_Speed', 'meas_status': 'PASS', 'meas_unit': 'mph', 'meas_upper_limit': 25.0, 'meas_value': 9.52, 'sensor': 'Anemometer', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879068435, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': nan, 'meas_name': 'Relative_Humidity', 'meas_status': 'PASS', 'meas_unit': '%', 'meas_upper_limit': nan, 'meas_value': 65.51, 'sensor': 'RH_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879068435, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 10.1, 'meas_name': 'Temperature', 'meas_status': 'PASS', 'meas_unit': 'deg F', 'meas_upper_limit': 120.4, 'meas_value': 70.52, 'sensor': 'Temperature_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879070675, 'meas_flag': nan, 'meas_method': nan}]
#
# [{'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 11.97, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879070675}, {'meas_value': 58.87, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879070675}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 71.38, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879070839}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 8.69, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879070839}, {'meas_value': 56.72, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879070839}]
#
# [{'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 11.97, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879070675}, {'meas_value': 58.87, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879070675}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 71.38, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879070839}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 8.69, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879070839}, {'meas_value': 56.72, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879070839}]
#
#    company event meas_datatype  meas_lower_limit          meas_name  \
# 0  EpiData  none        double               0.0         Wind_Speed
# 1  EpiData  none        double               NaN  Relative_Humidity
# 2  EpiData  none        double              10.1        Temperature
# 3  EpiData  none        double               0.0         Wind_Speed
# 4  EpiData  none        double               NaN  Relative_Humidity
#
#   meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 0        PASS       mph              25.0       11.97         Anemometer
# 1        PASS         %               NaN       58.87           RH_Probe
# 2        PASS     deg F             120.4       71.38  Temperature_Probe
# 3        PASS       mph              25.0        8.69         Anemometer
# 4        PASS         %               NaN       56.72           RH_Probe
#
#             site station             ts
# 0  San_Francisco   WSN-1  1661879070675
# 1  San_Francisco   WSN-1  1661879070675
# 2  San_Francisco   WSN-1  1661879070839
# 3  San_Francisco   WSN-1  1661879070839
# 4  San_Francisco   WSN-1  1661879070839
#
#    company event meas_datatype  meas_lower_limit          meas_name  \
# 0  EpiData  none        double               0.0         Wind_Speed
# 1  EpiData  none        double               NaN  Relative_Humidity
# 2  EpiData  none        double              10.1        Temperature
# 3  EpiData  none        double               0.0         Wind_Speed
# 4  EpiData  none        double               NaN  Relative_Humidity
#
#   meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 0        PASS       mph              25.0       11.97         Anemometer
# 1        PASS         %               NaN       58.87           RH_Probe
# 2        PASS     deg F             120.4       71.38  Temperature_Probe
# 3        PASS       mph              25.0        8.69         Anemometer
# 4        PASS         %               NaN       56.72           RH_Probe
#
#             site station             ts meas_flag meas_method
# 0  San_Francisco   WSN-1  1661879070675       NaN         NaN
# 1  San_Francisco   WSN-1  1661879070675       NaN         NaN
# 2  San_Francisco   WSN-1  1661879070839       NaN         NaN
# 3  San_Francisco   WSN-1  1661879070839       NaN         NaN
# 4  San_Francisco   WSN-1  1661879070839       NaN         NaN
#
# [{'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 0.0, 'meas_name': 'Wind_Speed', 'meas_status': 'PASS', 'meas_unit': 'mph', 'meas_upper_limit': 25.0, 'meas_value': 11.97, 'sensor': 'Anemometer', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879070675, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': nan, 'meas_name': 'Relative_Humidity', 'meas_status': 'PASS', 'meas_unit': '%', 'meas_upper_limit': nan, 'meas_value': 58.87, 'sensor': 'RH_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879070675, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 10.1, 'meas_name': 'Temperature', 'meas_status': 'PASS', 'meas_unit': 'deg F', 'meas_upper_limit': 120.4, 'meas_value': 71.38, 'sensor': 'Temperature_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879070839, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 0.0, 'meas_name': 'Wind_Speed', 'meas_status': 'PASS', 'meas_unit': 'mph', 'meas_upper_limit': 25.0, 'meas_value': 8.69, 'sensor': 'Anemometer', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879070839, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': nan, 'meas_name': 'Relative_Humidity', 'meas_status': 'PASS', 'meas_unit': '%', 'meas_upper_limit': nan, 'meas_value': 56.72, 'sensor': 'RH_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879070839, 'meas_flag': nan, 'meas_method': nan}]
#
# [{'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 72.07, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879070986}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 9.47, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879070986}, {'meas_value': 63.01, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879070986}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 72.28999999999999, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879071145}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 8.22, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879071145}]
# [{'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 72.07, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879070986}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 9.47, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879070986}, {'meas_value': 63.01, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879070986}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 72.28999999999999, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879071145}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 8.22, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879071145}]
#
#    company event meas_datatype  meas_lower_limit          meas_name  \
# 0  EpiData  none        double              10.1        Temperature
# 1  EpiData  none        double               0.0         Wind_Speed
# 2  EpiData  none        double               NaN  Relative_Humidity
# 3  EpiData  none        double              10.1        Temperature
# 4  EpiData  none        double               0.0         Wind_Speed
#
#   meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 0        PASS     deg F             120.4       72.07  Temperature_Probe
# 1        PASS       mph              25.0        9.47         Anemometer
# 2        PASS         %               NaN       63.01           RH_Probe
# 3        PASS     deg F             120.4       72.29  Temperature_Probe
# 4        PASS       mph              25.0        8.22         Anemometer
#
#             site station             ts
# 0  San_Francisco   WSN-1  1661879070986
# 1  San_Francisco   WSN-1  1661879070986
# 2  San_Francisco   WSN-1  1661879070986
# 3  San_Francisco   WSN-1  1661879071145
# 4  San_Francisco   WSN-1  1661879071145
#
#    company event meas_datatype  meas_lower_limit          meas_name  \
# 0  EpiData  none        double              10.1        Temperature
# 1  EpiData  none        double               0.0         Wind_Speed
# 2  EpiData  none        double               NaN  Relative_Humidity
# 3  EpiData  none        double              10.1        Temperature
# 4  EpiData  none        double               0.0         Wind_Speed
#
#   meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 0        PASS     deg F             120.4       72.07  Temperature_Probe
# 1        PASS       mph              25.0        9.47         Anemometer
# 2        PASS         %               NaN       63.01           RH_Probe
# 3        PASS     deg F             120.4       72.29  Temperature_Probe
# 4        PASS       mph              25.0        8.22         Anemometer
#
#             site station             ts meas_flag meas_method
# 0  San_Francisco   WSN-1  1661879070986       NaN         NaN
# 1  San_Francisco   WSN-1  1661879070986       NaN         NaN
# 2  San_Francisco   WSN-1  1661879070986       NaN         NaN
# 3  San_Francisco   WSN-1  1661879071145       NaN         NaN
# 4  San_Francisco   WSN-1  1661879071145       NaN         NaN
#
# [{'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 10.1, 'meas_name': 'Temperature', 'meas_status': 'PASS', 'meas_unit': 'deg F', 'meas_upper_limit': 120.4, 'meas_value': 72.07, 'sensor': 'Temperature_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879070986, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 0.0, 'meas_name': 'Wind_Speed', 'meas_status': 'PASS', 'meas_unit': 'mph', 'meas_upper_limit': 25.0, 'meas_value': 9.47, 'sensor': 'Anemometer', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879070986, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': nan, 'meas_name': 'Relative_Humidity', 'meas_status': 'PASS', 'meas_unit': '%', 'meas_upper_limit': nan, 'meas_value': 63.01, 'sensor': 'RH_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879070986, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 10.1, 'meas_name': 'Temperature', 'meas_status': 'PASS', 'meas_unit': 'deg F', 'meas_upper_limit': 120.4, 'meas_value': 72.28999999999999, 'sensor': 'Temperature_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879071145, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 0.0, 'meas_name': 'Wind_Speed', 'meas_status': 'PASS', 'meas_unit': 'mph', 'meas_upper_limit': 25.0, 'meas_value': 8.22, 'sensor': 'Anemometer', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879071145, 'meas_flag': nan, 'meas_method': nan}]
#
# [{'meas_value': 61.57, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879071145}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 70.87, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879072707}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 7.63, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879072707}, {'meas_value': 67.19, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879072707}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 71.03, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879072850}]
#
# [{'meas_value': 61.57, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879071145}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 70.87, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879072707}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 7.63, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879072707}, {'meas_value': 67.19, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879072707}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 71.03, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879072850}]
#
#    company event meas_datatype  meas_lower_limit          meas_name  \
# 0  EpiData  none        double               NaN  Relative_Humidity
# 1  EpiData  none        double              10.1        Temperature
# 2  EpiData  none        double               0.0         Wind_Speed
# 3  EpiData  none        double               NaN  Relative_Humidity
# 4  EpiData  none        double              10.1        Temperature
#
#   meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 0        PASS         %               NaN       61.57           RH_Probe
# 1        PASS     deg F             120.4       70.87  Temperature_Probe
# 2        PASS       mph              25.0        7.63         Anemometer
# 3        PASS         %               NaN       67.19           RH_Probe
# 4        PASS     deg F             120.4       71.03  Temperature_Probe
#
#             site station             ts
# 0  San_Francisco   WSN-1  1661879071145
# 1  San_Francisco   WSN-1  1661879072707
# 2  San_Francisco   WSN-1  1661879072707
# 3  San_Francisco   WSN-1  1661879072707
# 4  San_Francisco   WSN-1  1661879072850
#
#    company event meas_datatype  meas_lower_limit          meas_name  \
# 0  EpiData  none        double               NaN  Relative_Humidity
# 1  EpiData  none        double              10.1        Temperature
# 2  EpiData  none        double               0.0         Wind_Speed
# 3  EpiData  none        double               NaN  Relative_Humidity
# 4  EpiData  none        double              10.1        Temperature
#
#   meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 0        PASS         %               NaN       61.57           RH_Probe
# 1        PASS     deg F             120.4       70.87  Temperature_Probe
# 2        PASS       mph              25.0        7.63         Anemometer
# 3        PASS         %               NaN       67.19           RH_Probe
# 4        PASS     deg F             120.4       71.03  Temperature_Probe
#
#             site station             ts meas_flag meas_method
# 0  San_Francisco   WSN-1  1661879071145       NaN         NaN
# 1  San_Francisco   WSN-1  1661879072707       NaN         NaN
# 2  San_Francisco   WSN-1  1661879072707       NaN         NaN
# 3  San_Francisco   WSN-1  1661879072707       NaN         NaN
# 4  San_Francisco   WSN-1  1661879072850       NaN         NaN
#
# [{'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': nan, 'meas_name': 'Relative_Humidity', 'meas_status': 'PASS', 'meas_unit': '%', 'meas_upper_limit': nan, 'meas_value': 61.57, 'sensor': 'RH_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879071145, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 10.1, 'meas_name': 'Temperature', 'meas_status': 'PASS', 'meas_unit': 'deg F', 'meas_upper_limit': 120.4, 'meas_value': 70.87, 'sensor': 'Temperature_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879072707, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 0.0, 'meas_name': 'Wind_Speed', 'meas_status': 'PASS', 'meas_unit': 'mph', 'meas_upper_limit': 25.0, 'meas_value': 7.63, 'sensor': 'Anemometer', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879072707, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': nan, 'meas_name': 'Relative_Humidity', 'meas_status': 'PASS', 'meas_unit': '%', 'meas_upper_limit': nan, 'meas_value': 67.19, 'sensor': 'RH_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879072707, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 10.1, 'meas_name': 'Temperature', 'meas_status': 'PASS', 'meas_unit': 'deg F', 'meas_upper_limit': 120.4, 'meas_value': 71.03, 'sensor': 'Temperature_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879072850, 'meas_flag': nan, 'meas_method': nan}]
#
# [{'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 11.2, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879072850}, {'meas_value': 49.48, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879072850}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 71.55, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879073007}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 6.17, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879073007}, {'meas_value': 55.55, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879073007}]
#
# [{'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 11.2, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879072850}, {'meas_value': 49.48, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879072850}, {'meas_name': 'Temperature', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 71.55, 'site': 'San_Francisco', 'meas_lower_limit': 10.1, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Temperature_Probe', 'meas_upper_limit': 120.4, 'event': 'none', 'meas_unit': 'deg F', 'ts': 1661879073007}, {'meas_name': 'Wind_Speed', 'meas_datatype': 'double', 'meas_status': 'PASS', 'meas_value': 6.17, 'site': 'San_Francisco', 'meas_lower_limit': 0.0, 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'Anemometer', 'meas_upper_limit': 25.0, 'event': 'none', 'meas_unit': 'mph', 'ts': 1661879073007}, {'meas_value': 55.55, 'meas_name': 'Relative_Humidity', 'site': 'San_Francisco', 'meas_datatype': 'double', 'station': 'WSN-1', 'company': 'EpiData', 'sensor': 'RH_Probe', 'meas_status': 'PASS', 'event': 'none', 'meas_unit': '%', 'ts': 1661879073007}]
#    company event meas_datatype  meas_lower_limit          meas_name  \
# 0  EpiData  none        double               0.0         Wind_Speed
# 1  EpiData  none        double               NaN  Relative_Humidity
# 2  EpiData  none        double              10.1        Temperature
# 3  EpiData  none        double               0.0         Wind_Speed
# 4  EpiData  none        double               NaN  Relative_Humidity
#
#   meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 0        PASS       mph              25.0       11.20         Anemometer
# 1        PASS         %               NaN       49.48           RH_Probe
# 2        PASS     deg F             120.4       71.55  Temperature_Probe
# 3        PASS       mph              25.0        6.17         Anemometer
# 4        PASS         %               NaN       55.55           RH_Probe
#
#             site station             ts
# 0  San_Francisco   WSN-1  1661879072850
# 1  San_Francisco   WSN-1  1661879072850
# 2  San_Francisco   WSN-1  1661879073007
# 3  San_Francisco   WSN-1  1661879073007
# 4  San_Francisco   WSN-1  1661879073007
#
#    company event meas_datatype  meas_lower_limit          meas_name  \
# 0  EpiData  none        double               0.0         Wind_Speed
# 1  EpiData  none        double               NaN  Relative_Humidity
# 2  EpiData  none        double              10.1        Temperature
# 3  EpiData  none        double               0.0         Wind_Speed
# 4  EpiData  none        double               NaN  Relative_Humidity
#
#   meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 0        PASS       mph              25.0       11.20         Anemometer
# 1        PASS         %               NaN       49.48           RH_Probe
# 2        PASS     deg F             120.4       71.55  Temperature_Probe
# 3        PASS       mph              25.0        6.17         Anemometer
# 4        PASS         %               NaN       55.55           RH_Probe
#
#             site station             ts meas_flag meas_method
# 0  San_Francisco   WSN-1  1661879072850       NaN         NaN
# 1  San_Francisco   WSN-1  1661879072850       NaN         NaN
# 2  San_Francisco   WSN-1  1661879073007       NaN         NaN
# 3  San_Francisco   WSN-1  1661879073007       NaN         NaN
# 4  San_Francisco   WSN-1  1661879073007       NaN         NaN
#
# [{'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 0.0, 'meas_name': 'Wind_Speed', 'meas_status': 'PASS', 'meas_unit': 'mph', 'meas_upper_limit': 25.0, 'meas_value': 11.2, 'sensor': 'Anemometer', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879072850, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': nan, 'meas_name': 'Relative_Humidity', 'meas_status': 'PASS', 'meas_unit': '%', 'meas_upper_limit': nan, 'meas_value': 49.48, 'sensor': 'RH_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879072850, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 10.1, 'meas_name': 'Temperature', 'meas_status': 'PASS', 'meas_unit': 'deg F', 'meas_upper_limit': 120.4, 'meas_value': 71.55, 'sensor': 'Temperature_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879073007, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': 0.0, 'meas_name': 'Wind_Speed', 'meas_status': 'PASS', 'meas_unit': 'mph', 'meas_upper_limit': 25.0, 'meas_value': 6.17, 'sensor': 'Anemometer', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879073007, 'meas_flag': nan, 'meas_method': nan}, {'company': 'EpiData', 'event': 'none', 'meas_datatype': 'double', 'meas_lower_limit': nan, 'meas_name': 'Relative_Humidity', 'meas_status': 'PASS', 'meas_unit': '%', 'meas_upper_limit': nan, 'meas_value': 55.55, 'sensor': 'RH_Probe', 'site': 'San_Francisco', 'station': 'WSN-1', 'ts': 1661879073007, 'meas_flag': nan, 'meas_method': nan}]

# %% [markdown]
# <h3>Data Ingestion</h3>
# <p>We can now start data ingestion from simulated wireless sensor network. To do so, you can download and run the <i>sensor_data_ingest_with_outliers.py</i> example shown in the image below.</p>
# <img src="../static/jupyter_tree.png">

# %% [markdown]
# <h3>Data Query and Visualization</h3>

# %% [markdown]
# <p>We will query and visualize processed data is using <i>ec.query_measurements_cleansed() and ec.query_measurements_summary()</i> functions. For our example, we specify paramaters that match sample data set, and query the aggregated values using <i>ec.query_measurements_summary()</i> function call.</p>

# %%
# QUERY MEASUREMENTS_CLEANSED TABLE

# primary_key={"company": "Company-2", "site": "Site-1", "device_group":"1000", "tester": "Station-1"}
primary_key={"company": "EpiData", "site": "San_Francisco", "station":"WSN-1", "sensor": ["Temperature_Probe","Anemometer","RH_Probe"]}
start_time = datetime.strptime('1/1/2022 00:00:00', '%m/%d/%Y %H:%M:%S')
stop_time = datetime.strptime('1/1/2023 00:00:00', '%m/%d/%Y %H:%M:%S')

df_cleansed = ec.query_measurements_cleansed(primary_key, start_time, stop_time)

print(df_cleansed.tail(10))
# Out:
#     company event meas_datatype  meas_lower_limit meas_method    meas_name  \
# 90  EpiData  none        double              10.1              Temperature
# 91  EpiData  none        double              10.1              Temperature
# 92  EpiData  none        double              10.1              Temperature
# 93  EpiData  none        double              10.1              Temperature
# 94  EpiData  none        double              10.1              Temperature
# 95  EpiData  none        double              10.1              Temperature
# 96  EpiData  none        double              10.1              Temperature
# 97  EpiData  none        double              10.1              Temperature
# 98  EpiData  none        double              10.1              Temperature
# 99  EpiData  none        double              10.1              Temperature
#
#    meas_status meas_unit  meas_upper_limit  meas_value             sensor  \
# 90        PASS     deg F             120.4       70.70  Temperature_Probe
# 91        PASS     deg F             120.4       70.98  Temperature_Probe
# 92        PASS     deg F             120.4       71.14  Temperature_Probe
# 93        PASS     deg F             120.4       70.52  Temperature_Probe
# 94        PASS     deg F             120.4       71.38  Temperature_Probe
# 95        PASS     deg F             120.4       72.07  Temperature_Probe
# 96        PASS     deg F             120.4       72.29  Temperature_Probe
# 97        PASS     deg F             120.4       70.87  Temperature_Probe
# 98        PASS     deg F             120.4       71.03  Temperature_Probe
# 99        PASS     deg F             120.4       71.55  Temperature_Probe
#
#              site station             ts
# 90  San_Francisco   WSN-1  1661879068091
# 91  San_Francisco   WSN-1  1661879068261
# 92  San_Francisco   WSN-1  1661879068435
# 93  San_Francisco   WSN-1  1661879070675
# 94  San_Francisco   WSN-1  1661879070839
# 95  San_Francisco   WSN-1  1661879070986
# 96  San_Francisco   WSN-1  1661879071145
# 97  San_Francisco   WSN-1  1661879072707
# 98  San_Francisco   WSN-1  1661879072850
# 99  San_Francisco   WSN-1  1661879073007

# %%
# QUERY MEASUREMNTS_SUMMARY TABLE

# primary_key={"company": "Company-2", "site": "Site-1", "device_group":"1000", "tester": "Station-1"}
primary_key={"company": "EpiData", "site": "San_Francisco", "station":"WSN-1", "sensor": ["Temperature_Probe","Anemometer","RH_Probe"]}
start_time = datetime.strptime('1/1/2022 00:00:00', '%m/%d/%Y %H:%M:%S')
stop_time = datetime.strptime('1/1/2023 00:00:00', '%m/%d/%Y %H:%M:%S')

df_summary = ec.query_measurements_summary(primary_key, start_time, stop_time)
print(df_summary.tail(5))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# <h3>Stop Stream Analytics</h3>
# <p>The transformations can be stopped at any time via <i>esc.stop_streaming()</i> function call<p>

# %%
#Stop current near real-time processing
esc.stop_streaming()

# %% [markdown]
# <h2>Next Steps</h2>
# <p>Congratulations, you have successfully perfomed near real-time analytics on sample data aquired by a simulated wireless sensor network. The next step is to explore various capabilities of EpiData by creating your own custom analytics application!</p>
